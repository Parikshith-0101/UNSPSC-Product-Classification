# %% [markdown]
# ## EDA

# %%
import pandas as pd
import sklearn as sk
import numpy as np

# %%
df=pd.read_csv("G:/Dylog_Internship_Assessments/data/dylog_unspsc_data.csv")
df.head(5)
# Out:
#    Segment Code                                       Segment Name  \
# 0      10000000  Live Plant and Animal Material and Accessories...
# 1      10000000  Live Plant and Animal Material and Accessories...
# 2      10000000  Live Plant and Animal Material and Accessories...
# 3      10000000  Live Plant and Animal Material and Accessories...
# 4      10000000  Live Plant and Animal Material and Accessories...
#
#    Family Code   Family Name  Class Code Class Name  Commodity Code  \
# 0     10100000  Live animals    10101500  Livestock        10101501
# 1     10100000  Live animals    10101500  Livestock        10101502
# 2     10100000  Live animals    10101500  Livestock        10101504
# 3     10100000  Live animals    10101500  Livestock        10101505
# 4     10100000  Live animals    10101500  Livestock        10101506
#
#   Commodity Name
# 0           Cats
# 1           Dogs
# 2           Mink
# 3           Rats
# 4         Horses

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71502 entries, 0 to 71501
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Segment Code    71502 non-null  int64
#  1   Segment Name    71502 non-null  object
#  2   Family Code     71502 non-null  int64
#  3   Family Name     71502 non-null  object
#  4   Class Code      71502 non-null  int64
#  5   Class Name      71502 non-null  object
#  6   Commodity Code  71502 non-null  int64
#  7   Commodity Name  71502 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 4.4+ MB

# %%
##checking for null and missing values
df.isna().sum()
# Out:
# Segment Code      0
# Segment Name      0
# Family Code       0
# Family Name       0
# Class Code        0
# Class Name        0
# Commodity Code    0
# Commodity Name    0
# dtype: int64

# %%
##checking for duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# Segment Code         57
# Segment Name         57
# Family Code         465
# Family Name         465
# Class Code         5313
# Class Name         5313
# Commodity Code    71502
# Commodity Name    71502
# dtype: int64

# %% [markdown]
# Therefore we can consider that, this dataset is clean. We have a unique Commodity Code for each commodity in dataset.

# %%
#now we are going to create a corpus for retriver
df['corpus']=(df["Segment Name"]+" "+df["Family Name"]+" "+df["Class Name"]+" "+df["Commodity Name"]).str.lower()
df["corpus"].head(4)
df["corpus"][0]
# Out:
# 'live plant and animal material and accessories and supplies live animals livestock cats'

# %%
from langchain_core.documents import Document
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS

# %%
chunks=[]
for i,row in df.iterrows():
    doc=Document(
        page_content=row["corpus"],
        metadata={
            "Segment Code": row["Segment Code"],
            "Segment Name": row["Segment Name"],
            "Family Code": row["Family Code"],
            "Family Name": row["Family Name"],
            "Class Code": row["Class Code"],
            "Class Name": row["Class Name"],
            "Commodity Code": row["Commodity Code"],
            "Commodity Name": row["Commodity Name"],
        }
    )
    chunks.append(doc)

print(chunks[0])
# Out:
# page_content='live plant and animal material and accessories and supplies live animals livestock cats' metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10100000, 'Family Name': 'Live animals', 'Class Code': 10101500, 'Class Name': 'Livestock', 'Commodity Code': 10101501, 'Commodity Name': 'Cats'}

# %%
#successfully converted the dataset into documents 
print(chunks[38024])
# Out:
# page_content='food beverage and tobacco products fresh vegetables chicories salad king chicory' metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50400000, 'Family Name': 'Fresh vegetables', 'Class Code': 50402900, 'Class Name': 'Chicories', 'Commodity Code': 50402907, 'Commodity Name': 'Salad king chicory'}

# %%
embeddings=HuggingFaceEmbeddings(
    model_name="all-MiniLM-L6-v2"
)

# %%
#small portion of dataset just to check
#small_shunk=chunks[:500]

# %%
# vectorstore=FAISS.from_documents(
#     documents=chunks,
#     embedding=embeddings,
# )

# %%
# vectorstore.save_local("faiss.index")

# %%
loaded_vectorstore=FAISS.load_local(
    "faiss.index",
    embeddings,
    allow_dangerous_deserialization=True,
)
num_documents = len(loaded_vectorstore.docstore._dict)
num_documents
# Out:
# 71502

# %%
#addressing the search queries sample
loaded_vectorstore.similarity_search(query="cat snacks",k=5)
# Out:
# [Document(id='3269fd11-28f7-49d4-b38f-a6860b73803e', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10120000, 'Family Name': 'Animal feed', 'Class Code': 10121800, 'Class Name': 'Dog and cat food', 'Commodity Code': 10121805, 'Commodity Name': 'Moist food for cats'}, page_content='live plant and animal material and accessories and supplies animal feed dog and cat food moist food for cats'),
#  Document(id='ad157682-7e16-4b54-919a-ab665e8402d8', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10120000, 'Family Name': 'Animal feed', 'Class Code': 10121800, 'Class Name': 'Dog and cat food', 'Commodity Code': 10121804, 'Commodity Name': 'Dry food for cats'}, page_content='live plant and animal material and accessories and supplies animal feed dog and cat food dry food for cats'),
#  Document(id='e487aa78-d96d-40fb-ada1-d34cd276fb0f', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10120000, 'Family Name': 'Animal feed', 'Class Code': 10121800, 'Class Name': 'Dog and cat food', 'Commodity Code': 10121806, 'Commodity Name': 'Treats or snacks for cats or dogs'}, page_content='live plant and animal material and accessories and supplies animal feed dog and cat food treats or snacks for cats or dogs'),
#  Document(id='0000816f-89bc-4535-9bba-aba783d494c3', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50190000, 'Family Name': 'Prepared and preserved foods', 'Class Code': 50192100, 'Class Name': 'Snack foods', 'Commodity Code': 50192109, 'Commodity Name': 'Crisps or chips or pretzels or mixes'}, page_content='food beverage and tobacco products prepared and preserved foods snack foods crisps or chips or pretzels or mixes'),
#  Document(id='2fa04ee6-c7bf-4415-9099-2edb416b0531', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10100000, 'Family Name': 'Live animals', 'Class Code': 10101500, 'Class Name': 'Livestock', 'Commodity Code': 10101501, 'Commodity Name': 'Cats'}, page_content='live plant and animal material and accessories and supplies live animals livestock cats')]

# %%
loaded_vectorstore.similarity_search_with_relevance_scores(query="bird seeds parrot food",k=100)
# Out:
# [(Document(id='694a7c08-3f6c-40e4-a403-bab23cd43f4a', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10120000, 'Family Name': 'Animal feed', 'Class Code': 10121600, 'Class Name': 'Bird and fowl food', 'Commodity Code': 10121602, 'Commodity Name': 'Bird seed'}, page_content='live plant and animal material and accessories and supplies animal feed bird and fowl food bird seed'),
#   np.float32(0.47228205)),
#  (Document(id='990b20bd-b536-45df-b48a-3b2b3ecc0f96', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50130000, 'Family Name': 'Dairy products and eggs', 'Class Code': 50131600, 'Class Name': 'Eggs and egg substitutes', 'Commodity Code': 50131624, 'Commodity Name': 'In shell nest run egg from birds other than chickens'}, page_content='food beverage and tobacco products dairy products and eggs eggs and egg substitutes in shell nest run egg from birds other than chickens'),
#   np.float32(0.42992085)),
#  (Document(id='1cd9bb44-290a-4fe3-8654-f6de1bee6198', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50130000, 'Family Name': 'Dairy products and eggs', 'Class Code': 50131600, 'Class Name': 'Eggs and egg substitutes', 'Commodity Code': 50131622, 'Commodity Name': 'In shell table egg from specialty birds'}, page_content='food beverage and tobacco products dairy products and eggs eggs and egg substitutes in shell table egg from specialty birds'),
#   np.float32(0.40866375)),
#  (Document(id='0c07f8ba-452d-4f95-b027-4e439d4c4fd2', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10120000, 'Family Name': 'Animal feed', 'Class Code': 10121600, 'Class Name': 'Bird and fowl food', 'Commodity Code': 10121601, 'Commodity Name': 'Live food for birds'}, page_content='live plant and animal material and accessories and supplies animal feed bird and fowl food live food for birds'),
#   np.float32(0.39652878)),
#  (Document(id='67bd9aa1-2481-4d4a-b8ff-8434206020ff', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50400000, 'Family Name': 'Fresh vegetables', 'Class Code': 50401700, 'Class Name': 'Avocados', 'Commodity Code': 50401776, 'Commodity Name': 'West indian seedling avocado'}, page_content='food beverage and tobacco products fresh vegetables avocados west indian seedling avocado'),
#   np.float32(0.36864424)),
#  (Document(id='f19dfaa0-239d-4648-a777-eedfc69080b0', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50400000, 'Family Name': 'Fresh vegetables', 'Class Code': 50401700, 'Class Name': 'Avocados', 'Commodity Code': 50401733, 'Commodity Name': 'Guatemalan seedling avocados'}, page_content='food beverage and tobacco products fresh vegetables avocados guatemalan seedling avocados'),
#   np.float32(0.36138642)),
#  (Document(id='707c4aa8-840e-4b02-809d-050f8270902f', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50130000, 'Family Name': 'Dairy products and eggs', 'Class Code': 50131600, 'Class Name': 'Eggs and egg substitutes', 'Commodity Code': 50131634, 'Commodity Name': 'Egg extract from birds other than chickens'}, page_content='food beverage and tobacco products dairy products and eggs eggs and egg substitutes egg extract from birds other than chickens'),
#   np.float32(0.35389233)),
#  (Document(id='88598142-7eab-411c-a46e-8a7032da5499', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10120000, 'Family Name': 'Animal feed', 'Class Code': 10121600, 'Class Name': 'Bird and fowl food', 'Commodity Code': 10121604, 'Commodity Name': 'Poultry food'}, page_content='live plant and animal material and accessories and supplies animal feed bird and fowl food poultry food'),
#   np.float32(0.34734434)),
#  (Document(id='e8a1a154-8da6-405f-a2ca-ff0ac70824dd', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10120000, 'Family Name': 'Animal feed', 'Class Code': 10121600, 'Class Name': 'Bird and fowl food', 'Commodity Code': 10121603, 'Commodity Name': 'Bird treats or snacks'}, page_content='live plant and animal material and accessories and supplies animal feed bird and fowl food bird treats or snacks'),
#   np.float32(0.346462)),
#  (Document(id='15b1a1c9-df93-4e88-9f6b-b66348434183', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50130000, 'Family Name': 'Dairy products and eggs', 'Class Code': 50131600, 'Class Name': 'Eggs and egg substitutes', 'Commodity Code': 50131628, 'Commodity Name': 'Cooked egg from birds other than chickens'}, page_content='food beverage and tobacco products dairy products and eggs eggs and egg substitutes cooked egg from birds other than chickens'),
#   np.float32(0.3407086)),
#  (Document(id='2fa0a1c2-c587-4aa1-ad28-2c5fa748d8ac', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50410000, 'Family Name': 'Organic fresh vegetables', 'Class Code': 50411700, 'Class Name': 'Organic avocados', 'Commodity Code': 50411776, 'Commodity Name': 'Organic west indian seedling avocado'}, page_content='food beverage and tobacco products organic fresh vegetables organic avocados organic west indian seedling avocado'),
#   np.float32(0.33435506)),
#  (Document(id='a0ae9ca6-19c8-49d7-94a5-346bfbaadb81', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50410000, 'Family Name': 'Organic fresh vegetables', 'Class Code': 50411700, 'Class Name': 'Organic avocados', 'Commodity Code': 50411733, 'Commodity Name': 'Organic guatemalan seedling avocados'}, page_content='food beverage and tobacco products organic fresh vegetables organic avocados organic guatemalan seedling avocados'),
#   np.float32(0.32352507)),
#  (Document(id='ff45bbfb-a32e-4574-b7b8-4371cc79b828', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50100000, 'Family Name': 'Nuts and seeds', 'Class Code': 50101700, 'Class Name': 'Nuts and seeds', 'Commodity Code': 50101717, 'Commodity Name': 'Shelled nuts or seeds'}, page_content='food beverage and tobacco products nuts and seeds nuts and seeds shelled nuts or seeds'),
#   np.float32(0.32201636)),
#  (Document(id='640e12a1-5323-4eb6-b784-cd2a860bb070', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50130000, 'Family Name': 'Dairy products and eggs', 'Class Code': 50131600, 'Class Name': 'Eggs and egg substitutes', 'Commodity Code': 50131620, 'Commodity Name': 'In shell table egg from squabs or pigeons'}, page_content='food beverage and tobacco products dairy products and eggs eggs and egg substitutes in shell table egg from squabs or pigeons'),
#   np.float32(0.32115543)),
#  (Document(id='d7bc1e9f-b618-48fc-a8bc-74e6e01e96a0', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50130000, 'Family Name': 'Dairy products and eggs', 'Class Code': 50131600, 'Class Name': 'Eggs and egg substitutes', 'Commodity Code': 50131626, 'Commodity Name': 'In shell checked and dirty egg industrial from birds other than chickens'}, page_content='food beverage and tobacco products dairy products and eggs eggs and egg substitutes in shell checked and dirty egg industrial from birds other than chickens'),
#   np.float32(0.3208347)),
#  (Document(id='4366fbaa-d33b-456d-a82e-ec8df7866cb5', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50130000, 'Family Name': 'Dairy products and eggs', 'Class Code': 50131600, 'Class Name': 'Eggs and egg substitutes', 'Commodity Code': 50131623, 'Commodity Name': 'In shell nest run egg from chickens'}, page_content='food beverage and tobacco products dairy products and eggs eggs and egg substitutes in shell nest run egg from chickens'),
#   np.float32(0.31014323)),
#  (Document(id='08857fce-a72c-4d0d-958d-3451353df00a', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10150000, 'Family Name': 'Seeds and bulbs and seedlings and cuttings', 'Class Code': 10151600, 'Class Name': 'Cereal seeds', 'Commodity Code': 10151606, 'Commodity Name': 'Sesame seeds'}, page_content='live plant and animal material and accessories and supplies seeds and bulbs and seedlings and cuttings cereal seeds sesame seeds'),
#   np.float32(0.2912618)),
#  (Document(id='fc3fd903-6635-44fd-b3a1-a5cf62743e8d', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50580000, 'Family Name': 'Non GMO fresh vegetables', 'Class Code': 50581700, 'Class Name': 'Non GMO avocados', 'Commodity Code': 50581733, 'Commodity Name': 'Non GMO guatemalan seedling avocados'}, page_content='food beverage and tobacco products non gmo fresh vegetables non gmo avocados non gmo guatemalan seedling avocados'),
#   np.float32(0.2908147)),
#  (Document(id='68c2c035-719d-4341-972c-75050920d606', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50580000, 'Family Name': 'Non GMO fresh vegetables', 'Class Code': 50581700, 'Class Name': 'Non GMO avocados', 'Commodity Code': 50581776, 'Commodity Name': 'Non GMO west indian seedling avocado'}, page_content='food beverage and tobacco products non gmo fresh vegetables non gmo avocados non gmo west indian seedling avocado'),
#   np.float32(0.2895196)),
#  (Document(id='b7b5fe40-9c7a-4c1c-abb3-6311d6a061a0', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50300000, 'Family Name': 'Fresh fruits', 'Class Code': 50304600, 'Class Name': 'Melons', 'Commodity Code': 50304636, 'Commodity Name': 'Peacock melons'}, page_content='food beverage and tobacco products fresh fruits melons peacock melons'),
#   np.float32(0.28884524)),
#  (Document(id='d337b8e7-8b7c-4a47-a621-fb61b1bdc6fc', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50100000, 'Family Name': 'Nuts and seeds', 'Class Code': 50101700, 'Class Name': 'Nuts and seeds', 'Commodity Code': 50101716, 'Commodity Name': 'Whole nuts or seeds'}, page_content='food beverage and tobacco products nuts and seeds nuts and seeds whole nuts or seeds'),
#   np.float32(0.28326964)),
#  (Document(id='6c8a0404-cb52-4f9a-979d-275682eeb51d', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50420000, 'Family Name': 'Dried vegetables', 'Class Code': 50421700, 'Class Name': 'Dried avocados', 'Commodity Code': 50421776, 'Commodity Name': 'Dried west indian seedling avocados'}, page_content='food beverage and tobacco products dried vegetables dried avocados dried west indian seedling avocados'),
#   np.float32(0.28243828)),
#  (Document(id='73e4a553-fe82-4807-a2fb-0de8d6de37fa', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50420000, 'Family Name': 'Dried vegetables', 'Class Code': 50421700, 'Class Name': 'Dried avocados', 'Commodity Code': 50421733, 'Commodity Name': 'Dried guatemalan seedling avocados'}, page_content='food beverage and tobacco products dried vegetables dried avocados dried guatemalan seedling avocados'),
#   np.float32(0.27572882)),
#  (Document(id='a5420c59-d8e7-4f6e-842a-d6da404c0311', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50130000, 'Family Name': 'Dairy products and eggs', 'Class Code': 50131600, 'Class Name': 'Eggs and egg substitutes', 'Commodity Code': 50131631, 'Commodity Name': 'Egg products and substitutes from birds other than chickens'}, page_content='food beverage and tobacco products dairy products and eggs eggs and egg substitutes egg products and substitutes from birds other than chickens'),
#   np.float32(0.27392316)),
#  (Document(id='e8e4d2af-97c7-4c5f-a114-9e4504c49081', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10310000, 'Family Name': 'Fresh cut blooms of high species or variety count flowers', 'Class Code': 10317300, 'Class Name': 'Fresh cut tulips', 'Commodity Code': 10317329, 'Commodity Name': 'Fresh cut french white parrot tulip'}, page_content='live plant and animal material and accessories and supplies fresh cut blooms of high species or variety count flowers fresh cut tulips fresh cut french white parrot tulip'),
#   np.float32(0.2698797)),
#  (Document(id='bf13d20f-b042-42da-bbfc-43621deffc5c', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50130000, 'Family Name': 'Dairy products and eggs', 'Class Code': 50131600, 'Class Name': 'Eggs and egg substitutes', 'Commodity Code': 50131618, 'Commodity Name': 'In shell table egg from quails'}, page_content='food beverage and tobacco products dairy products and eggs eggs and egg substitutes in shell table egg from quails'),
#   np.float32(0.2691217)),
#  (Document(id='1cb8a9a8-4d43-4dd0-adce-1f1e91990614', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10410000, 'Family Name': 'Dried cut blooms of high species or variety count flowers', 'Class Code': 10417300, 'Class Name': 'Dried cut tulips', 'Commodity Code': 10417329, 'Commodity Name': 'Dried cut french white parrot tulip'}, page_content='live plant and animal material and accessories and supplies dried cut blooms of high species or variety count flowers dried cut tulips dried cut french white parrot tulip'),
#   np.float32(0.2690887)),
#  (Document(id='9c493ee3-bcbc-4a15-b048-b49df0f44793', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50430000, 'Family Name': 'Dried organic vegetables', 'Class Code': 50431700, 'Class Name': 'Dried organic avocados', 'Commodity Code': 50431776, 'Commodity Name': 'Dried organic west indian seedling avocados'}, page_content='food beverage and tobacco products dried organic vegetables dried organic avocados dried organic west indian seedling avocados'),
#   np.float32(0.2656687)),
#  (Document(id='53ac5151-106f-4184-b327-1267495a3ae9', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50110000, 'Family Name': 'Meat and poultry products', 'Class Code': 50111500, 'Class Name': 'Minimally processed meat and poultry products', 'Commodity Code': 50111560, 'Commodity Name': 'Pheasant, minimally processed with additions'}, page_content='food beverage and tobacco products meat and poultry products minimally processed meat and poultry products pheasant, minimally processed with additions'),
#   np.float32(0.26321995)),
#  (Document(id='7369ceca-1b7a-4943-abc3-8048bcc58e94', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10410000, 'Family Name': 'Dried cut blooms of high species or variety count flowers', 'Class Code': 10417300, 'Class Name': 'Dried cut tulips', 'Commodity Code': 10417328, 'Commodity Name': 'Dried cut french weber parrot tulip'}, page_content='live plant and animal material and accessories and supplies dried cut blooms of high species or variety count flowers dried cut tulips dried cut french weber parrot tulip'),
#   np.float32(0.25985807)),
#  (Document(id='eb4a2592-ef2c-4945-bfc0-1f5bcd53516f', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10310000, 'Family Name': 'Fresh cut blooms of high species or variety count flowers', 'Class Code': 10317300, 'Class Name': 'Fresh cut tulips', 'Commodity Code': 10317338, 'Commodity Name': 'Fresh cut parrot estella rijnveld tulip'}, page_content='live plant and animal material and accessories and supplies fresh cut blooms of high species or variety count flowers fresh cut tulips fresh cut parrot estella rijnveld tulip'),
#   np.float32(0.25964105)),
#  (Document(id='ba9aafe9-05a8-4a89-ac23-838c8872ab2c', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50430000, 'Family Name': 'Dried organic vegetables', 'Class Code': 50431700, 'Class Name': 'Dried organic avocados', 'Commodity Code': 50431733, 'Commodity Name': 'Dried organic guatemalan seedling avocados'}, page_content='food beverage and tobacco products dried organic vegetables dried organic avocados dried organic guatemalan seedling avocados'),
#   np.float32(0.259295)),
#  (Document(id='518ae020-252c-4b8d-8626-39ef5b21d409', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50130000, 'Family Name': 'Dairy products and eggs', 'Class Code': 50131600, 'Class Name': 'Eggs and egg substitutes', 'Commodity Code': 50131616, 'Commodity Name': 'In shell table egg from guineafowls'}, page_content='food beverage and tobacco products dairy products and eggs eggs and egg substitutes in shell table egg from guineafowls'),
#   np.float32(0.2573818)),
#  (Document(id='7c81ea28-3a44-4978-a257-83b5399b96dc', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10310000, 'Family Name': 'Fresh cut blooms of high species or variety count flowers', 'Class Code': 10317300, 'Class Name': 'Fresh cut tulips', 'Commodity Code': 10317328, 'Commodity Name': 'Fresh cut french weber parrot tulip'}, page_content='live plant and animal material and accessories and supplies fresh cut blooms of high species or variety count flowers fresh cut tulips fresh cut french weber parrot tulip'),
#   np.float32(0.2571543)),
#  (Document(id='b8f947a3-4dec-4bb2-8af0-9e2cdff5f328', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10310000, 'Family Name': 'Fresh cut blooms of high species or variety count flowers', 'Class Code': 10317300, 'Class Name': 'Fresh cut tulips', 'Commodity Code': 10317347, 'Commodity Name': 'Fresh cut parrot weber tulip'}, page_content='live plant and animal material and accessories and supplies fresh cut blooms of high species or variety count flowers fresh cut tulips fresh cut parrot weber tulip'),
#   np.float32(0.25575018)),
#  (Document(id='dd2d6966-2fbe-431d-b281-50d437afd089', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50400000, 'Family Name': 'Fresh vegetables', 'Class Code': 50401700, 'Class Name': 'Avocados', 'Commodity Code': 50401760, 'Commodity Name': 'Pinkerton avocados'}, page_content='food beverage and tobacco products fresh vegetables avocados pinkerton avocados'),
#   np.float32(0.25455803)),
#  (Document(id='8ad892a4-c98b-4c0f-8f01-896ee61c101e', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10310000, 'Family Name': 'Fresh cut blooms of high species or variety count flowers', 'Class Code': 10317300, 'Class Name': 'Fresh cut tulips', 'Commodity Code': 10317348, 'Commodity Name': 'Fresh cut parrot white tulip'}, page_content='live plant and animal material and accessories and supplies fresh cut blooms of high species or variety count flowers fresh cut tulips fresh cut parrot white tulip'),
#   np.float32(0.25346637)),
#  (Document(id='3852e5f8-6381-460b-afe9-b65d7dddfa67', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10310000, 'Family Name': 'Fresh cut blooms of high species or variety count flowers', 'Class Code': 10317300, 'Class Name': 'Fresh cut tulips', 'Commodity Code': 10317322, 'Commodity Name': 'Fresh cut french pink parrot tulip'}, page_content='live plant and animal material and accessories and supplies fresh cut blooms of high species or variety count flowers fresh cut tulips fresh cut french pink parrot tulip'),
#   np.float32(0.25329018)),
#  (Document(id='e31d8690-e5c4-4e5a-a6c4-2ef1ee093ab3', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10410000, 'Family Name': 'Dried cut blooms of high species or variety count flowers', 'Class Code': 10417300, 'Class Name': 'Dried cut tulips', 'Commodity Code': 10417338, 'Commodity Name': 'Dried cut parrot estella rijnveld tulip'}, page_content='live plant and animal material and accessories and supplies dried cut blooms of high species or variety count flowers dried cut tulips dried cut parrot estella rijnveld tulip'),
#   np.float32(0.25258607)),
#  (Document(id='80cd6671-9778-48c2-89bb-d7506af19bd2', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50440000, 'Family Name': 'Frozen vegetables', 'Class Code': 50441700, 'Class Name': 'Frozen avocados', 'Commodity Code': 50441733, 'Commodity Name': 'Frozen guatemalan seedling avocados'}, page_content='food beverage and tobacco products frozen vegetables frozen avocados frozen guatemalan seedling avocados'),
#   np.float32(0.25242674)),
#  (Document(id='f5fc56a4-539d-41dd-8d30-03e83d6603a2', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10310000, 'Family Name': 'Fresh cut blooms of high species or variety count flowers', 'Class Code': 10317300, 'Class Name': 'Fresh cut tulips', 'Commodity Code': 10317337, 'Commodity Name': 'Fresh cut parrot black tulip'}, page_content='live plant and animal material and accessories and supplies fresh cut blooms of high species or variety count flowers fresh cut tulips fresh cut parrot black tulip'),
#   np.float32(0.2522542)),
#  (Document(id='b95c4c64-a304-43f4-8367-daa3c5f6fb17', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10310000, 'Family Name': 'Fresh cut blooms of high species or variety count flowers', 'Class Code': 10317300, 'Class Name': 'Fresh cut tulips', 'Commodity Code': 10317340, 'Commodity Name': 'Fresh cut parrot green tulip'}, page_content='live plant and animal material and accessories and supplies fresh cut blooms of high species or variety count flowers fresh cut tulips fresh cut parrot green tulip'),
#   np.float32(0.25203633)),
#  (Document(id='26c4816c-6583-4703-8661-caf436d44a30', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10410000, 'Family Name': 'Dried cut blooms of high species or variety count flowers', 'Class Code': 10417300, 'Class Name': 'Dried cut tulips', 'Commodity Code': 10417322, 'Commodity Name': 'Dried cut french pink parrot tulip'}, page_content='live plant and animal material and accessories and supplies dried cut blooms of high species or variety count flowers dried cut tulips dried cut french pink parrot tulip'),
#   np.float32(0.2518651)),
#  (Document(id='d6fdd55e-38dd-4b3e-8c19-b98c84b1a05c', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10150000, 'Family Name': 'Seeds and bulbs and seedlings and cuttings', 'Class Code': 10151800, 'Class Name': 'Spice crop seeds and seedlings', 'Commodity Code': 10151813, 'Commodity Name': 'Sacha inchi seeds or seedlings'}, page_content='live plant and animal material and accessories and supplies seeds and bulbs and seedlings and cuttings spice crop seeds and seedlings sacha inchi seeds or seedlings'),
#   np.float32(0.25028563)),
#  (Document(id='356f9638-5694-41c3-914e-197d9b267431', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10310000, 'Family Name': 'Fresh cut blooms of high species or variety count flowers', 'Class Code': 10317300, 'Class Name': 'Fresh cut tulips', 'Commodity Code': 10317344, 'Commodity Name': 'Fresh cut parrot pink tulip'}, page_content='live plant and animal material and accessories and supplies fresh cut blooms of high species or variety count flowers fresh cut tulips fresh cut parrot pink tulip'),
#   np.float32(0.2499361)),
#  (Document(id='b6f3f58c-c321-4d53-9cc2-7b2f25c170ef', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10310000, 'Family Name': 'Fresh cut blooms of high species or variety count flowers', 'Class Code': 10317300, 'Class Name': 'Fresh cut tulips', 'Commodity Code': 10317345, 'Commodity Name': 'Fresh cut parrot red tulip'}, page_content='live plant and animal material and accessories and supplies fresh cut blooms of high species or variety count flowers fresh cut tulips fresh cut parrot red tulip'),
#   np.float32(0.24907523)),
#  (Document(id='cae47273-480c-4bc9-8454-df76cc56a51a', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10410000, 'Family Name': 'Dried cut blooms of high species or variety count flowers', 'Class Code': 10417300, 'Class Name': 'Dried cut tulips', 'Commodity Code': 10417340, 'Commodity Name': 'Dried cut parrot green tulip'}, page_content='live plant and animal material and accessories and supplies dried cut blooms of high species or variety count flowers dried cut tulips dried cut parrot green tulip'),
#   np.float32(0.24871355)),
#  (Document(id='957927b4-6096-4cd1-9bc0-3c9f91bc1c05', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10410000, 'Family Name': 'Dried cut blooms of high species or variety count flowers', 'Class Code': 10417300, 'Class Name': 'Dried cut tulips', 'Commodity Code': 10417337, 'Commodity Name': 'Dried cut parrot black tulip'}, page_content='live plant and animal material and accessories and supplies dried cut blooms of high species or variety count flowers dried cut tulips dried cut parrot black tulip'),
#   np.float32(0.24825853)),
#  (Document(id='32cfc28a-cee2-424f-9d48-b34e335dbc39', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10410000, 'Family Name': 'Dried cut blooms of high species or variety count flowers', 'Class Code': 10417300, 'Class Name': 'Dried cut tulips', 'Commodity Code': 10417347, 'Commodity Name': 'Dried cut parrot weber tulip'}, page_content='live plant and animal material and accessories and supplies dried cut blooms of high species or variety count flowers dried cut tulips dried cut parrot weber tulip'),
#   np.float32(0.24754119)),
#  (Document(id='f1fdead8-edf6-4554-9d5d-5425a102f730', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10310000, 'Family Name': 'Fresh cut blooms of high species or variety count flowers', 'Class Code': 10317300, 'Class Name': 'Fresh cut tulips', 'Commodity Code': 10317349, 'Commodity Name': 'Fresh cut parrot yellow tulip'}, page_content='live plant and animal material and accessories and supplies fresh cut blooms of high species or variety count flowers fresh cut tulips fresh cut parrot yellow tulip'),
#   np.float32(0.2458117)),
#  (Document(id='29099fe2-2ae6-49f2-af89-76c5ef0ebd45', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50440000, 'Family Name': 'Frozen vegetables', 'Class Code': 50441700, 'Class Name': 'Frozen avocados', 'Commodity Code': 50441776, 'Commodity Name': 'Frozen west indian seedling avocados'}, page_content='food beverage and tobacco products frozen vegetables frozen avocados frozen west indian seedling avocados'),
#   np.float32(0.24553281)),
#  (Document(id='9553f8fe-a79d-4637-862c-9343f2a4692f', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50300000, 'Family Name': 'Fresh fruits', 'Class Code': 50304900, 'Class Name': 'Nectarines', 'Commodity Code': 50304915, 'Commodity Name': 'Earliglo nectarines'}, page_content='food beverage and tobacco products fresh fruits nectarines earliglo nectarines'),
#   np.float32(0.24493009)),
#  (Document(id='f8a6ff85-2717-433c-9215-5196d872ac40', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50480000, 'Family Name': 'Fresh vegetable purees', 'Class Code': 50481800, 'Class Name': 'Avocado purees', 'Commodity Code': 50481876, 'Commodity Name': 'West indian seedling avocado purees'}, page_content='food beverage and tobacco products fresh vegetable purees avocado purees west indian seedling avocado purees'),
#   np.float32(0.244452)),
#  (Document(id='1da228a0-4984-4655-9ea1-c05999802900', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10410000, 'Family Name': 'Dried cut blooms of high species or variety count flowers', 'Class Code': 10417300, 'Class Name': 'Dried cut tulips', 'Commodity Code': 10417348, 'Commodity Name': 'Dried cut parrot white tulip'}, page_content='live plant and animal material and accessories and supplies dried cut blooms of high species or variety count flowers dried cut tulips dried cut parrot white tulip'),
#   np.float32(0.2440961)),
#  (Document(id='5dfd5e3e-4766-437e-ae3a-27e522d574d1', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50110000, 'Family Name': 'Meat and poultry products', 'Class Code': 50111500, 'Class Name': 'Minimally processed meat and poultry products', 'Commodity Code': 50111559, 'Commodity Name': 'Pheasant, minimally processed without additions'}, page_content='food beverage and tobacco products meat and poultry products minimally processed meat and poultry products pheasant, minimally processed without additions'),
#   np.float32(0.24397397)),
#  (Document(id='c5bfe4b6-e333-44cd-9225-309b3d90bdbd', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10150000, 'Family Name': 'Seeds and bulbs and seedlings and cuttings', 'Class Code': 10151600, 'Class Name': 'Cereal seeds', 'Commodity Code': 10151604, 'Commodity Name': 'Millet seeds'}, page_content='live plant and animal material and accessories and supplies seeds and bulbs and seedlings and cuttings cereal seeds millet seeds'),
#   np.float32(0.24301487)),
#  (Document(id='aeb0f83a-53c5-4319-9526-692633fbf67c', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10150000, 'Family Name': 'Seeds and bulbs and seedlings and cuttings', 'Class Code': 10151600, 'Class Name': 'Cereal seeds', 'Commodity Code': 10151610, 'Commodity Name': 'Rye seeds'}, page_content='live plant and animal material and accessories and supplies seeds and bulbs and seedlings and cuttings cereal seeds rye seeds'),
#   np.float32(0.24294853)),
#  (Document(id='a1738a42-2991-414e-9977-4e3295aa73ab', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10410000, 'Family Name': 'Dried cut blooms of high species or variety count flowers', 'Class Code': 10417300, 'Class Name': 'Dried cut tulips', 'Commodity Code': 10417345, 'Commodity Name': 'Dried cut parrot red tulip'}, page_content='live plant and animal material and accessories and supplies dried cut blooms of high species or variety count flowers dried cut tulips dried cut parrot red tulip'),
#   np.float32(0.24241239)),
#  (Document(id='b24d59f2-e6f0-440d-8e7b-2f0559abe6f3', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50110000, 'Family Name': 'Meat and poultry products', 'Class Code': 50112000, 'Class Name': 'Processed meat and poultry products', 'Commodity Code': 50112051, 'Commodity Name': 'Pheasant, processed with additions'}, page_content='food beverage and tobacco products meat and poultry products processed meat and poultry products pheasant, processed with additions'),
#   np.float32(0.24203825)),
#  (Document(id='04db60c7-5e08-4156-990c-25ba78dc5139', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50130000, 'Family Name': 'Dairy products and eggs', 'Class Code': 50131600, 'Class Name': 'Eggs and egg substitutes', 'Commodity Code': 50131632, 'Commodity Name': 'Decharacterized egg products from birds other than chickens'}, page_content='food beverage and tobacco products dairy products and eggs eggs and egg substitutes decharacterized egg products from birds other than chickens'),
#   np.float32(0.24200314)),
#  (Document(id='8a5d4c41-1756-4334-9d81-13d579788d9e', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50490000, 'Family Name': 'Organic fresh vegetable purees', 'Class Code': 50491700, 'Class Name': 'Organic avocado purees', 'Commodity Code': 50491776, 'Commodity Name': 'Organic west indian seedling avocado purees'}, page_content='food beverage and tobacco products organic fresh vegetable purees organic avocado purees organic west indian seedling avocado purees'),
#   np.float32(0.24199271)),
#  (Document(id='5651f014-c2a8-4ef5-97b3-c72665310d4a', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10410000, 'Family Name': 'Dried cut blooms of high species or variety count flowers', 'Class Code': 10417300, 'Class Name': 'Dried cut tulips', 'Commodity Code': 10417344, 'Commodity Name': 'Dried cut parrot pink tulip'}, page_content='live plant and animal material and accessories and supplies dried cut blooms of high species or variety count flowers dried cut tulips dried cut parrot pink tulip'),
#   np.float32(0.24170148)),
#  (Document(id='cb479f34-6ee7-46d9-91f6-ea16afe3a402', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10410000, 'Family Name': 'Dried cut blooms of high species or variety count flowers', 'Class Code': 10417300, 'Class Name': 'Dried cut tulips', 'Commodity Code': 10417349, 'Commodity Name': 'Dried cut parrot yellow tulip'}, page_content='live plant and animal material and accessories and supplies dried cut blooms of high species or variety count flowers dried cut tulips dried cut parrot yellow tulip'),
#   np.float32(0.2416203)),
#  (Document(id='a3023c95-8fae-43f6-8daa-07e40843f969', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10310000, 'Family Name': 'Fresh cut blooms of high species or variety count flowers', 'Class Code': 10317300, 'Class Name': 'Fresh cut tulips', 'Commodity Code': 10317342, 'Commodity Name': 'Fresh cut parrot orange tulip'}, page_content='live plant and animal material and accessories and supplies fresh cut blooms of high species or variety count flowers fresh cut tulips fresh cut parrot orange tulip'),
#   np.float32(0.24156088)),
#  (Document(id='0b27ba80-91b0-41b1-81f2-f45a9df8e4da', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10410000, 'Family Name': 'Dried cut blooms of high species or variety count flowers', 'Class Code': 10417300, 'Class Name': 'Dried cut tulips', 'Commodity Code': 10417342, 'Commodity Name': 'Dried cut parrot orange tulip'}, page_content='live plant and animal material and accessories and supplies dried cut blooms of high species or variety count flowers dried cut tulips dried cut parrot orange tulip'),
#   np.float32(0.24077189)),
#  (Document(id='4f8b67f1-5c7f-4c28-ab90-2c5535afe290', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10210000, 'Family Name': 'Live plants of high species or variety count flowers', 'Class Code': 10217300, 'Class Name': 'Live tulips', 'Commodity Code': 10217338, 'Commodity Name': 'Live parrot estella rijnveld tulip'}, page_content='live plant and animal material and accessories and supplies live plants of high species or variety count flowers live tulips live parrot estella rijnveld tulip'),
#   np.float32(0.24053264)),
#  (Document(id='1ac8c474-c5cc-42c5-8c94-b03bf4e3ef62', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10300000, 'Family Name': 'Fresh cut rose', 'Class Code': 10302700, 'Class Name': 'Fresh cut yellow rose', 'Commodity Code': 10302762, 'Commodity Name': 'Fresh cut parrot rose'}, page_content='live plant and animal material and accessories and supplies fresh cut rose fresh cut yellow rose fresh cut parrot rose'),
#   np.float32(0.24031872)),
#  (Document(id='85f2a8bd-b503-4304-b30d-983ee5774ee9', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10310000, 'Family Name': 'Fresh cut blooms of high species or variety count flowers', 'Class Code': 10317300, 'Class Name': 'Fresh cut tulips', 'Commodity Code': 10317314, 'Commodity Name': 'Fresh cut french flaming parrot tulip'}, page_content='live plant and animal material and accessories and supplies fresh cut blooms of high species or variety count flowers fresh cut tulips fresh cut french flaming parrot tulip'),
#   np.float32(0.23993516)),
#  (Document(id='133b3d97-cf03-4d75-a1c8-ac4bab2735c7', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10410000, 'Family Name': 'Dried cut blooms of high species or variety count flowers', 'Class Code': 10417300, 'Class Name': 'Dried cut tulips', 'Commodity Code': 10417314, 'Commodity Name': 'Dried cut french flaming parrot tulip'}, page_content='live plant and animal material and accessories and supplies dried cut blooms of high species or variety count flowers dried cut tulips dried cut french flaming parrot tulip'),
#   np.float32(0.23991293)),
#  (Document(id='fd010a4f-dbc9-401a-bc8c-d4d93ad750cf', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50450000, 'Family Name': 'Frozen organic vegetables', 'Class Code': 50451700, 'Class Name': 'Frozen organic avocados', 'Commodity Code': 50451733, 'Commodity Name': 'Frozen organic guatemalan seedling avocados'}, page_content='food beverage and tobacco products frozen organic vegetables frozen organic avocados frozen organic guatemalan seedling avocados'),
#   np.float32(0.23894072)),
#  (Document(id='904d29d3-2deb-467b-8fca-2f69a333f4f4', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50490000, 'Family Name': 'Organic fresh vegetable purees', 'Class Code': 50491700, 'Class Name': 'Organic avocado purees', 'Commodity Code': 50491733, 'Commodity Name': 'Organic guatemalan seedling avocado purees'}, page_content='food beverage and tobacco products organic fresh vegetable purees organic avocado purees organic guatemalan seedling avocado purees'),
#   np.float32(0.23628187)),
#  (Document(id='db59e0e8-0a4e-483d-a1d4-44142029bbec', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50300000, 'Family Name': 'Fresh fruits', 'Class Code': 50304900, 'Class Name': 'Nectarines', 'Commodity Code': 50304923, 'Commodity Name': 'Garden delight nectarines'}, page_content='food beverage and tobacco products fresh fruits nectarines garden delight nectarines'),
#   np.float32(0.23591691)),
#  (Document(id='617fffc7-8f34-4084-a28a-8cb5b5b40c39', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10150000, 'Family Name': 'Seeds and bulbs and seedlings and cuttings', 'Class Code': 10151600, 'Class Name': 'Cereal seeds', 'Commodity Code': 10151609, 'Commodity Name': 'Maize seeds'}, page_content='live plant and animal material and accessories and supplies seeds and bulbs and seedlings and cuttings cereal seeds maize seeds'),
#   np.float32(0.23445868)),
#  (Document(id='e960e76a-d688-4789-bdb0-8b4e6ad5d213', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50580000, 'Family Name': 'Non GMO fresh vegetables', 'Class Code': 50585800, 'Class Name': 'Non GMO shallots', 'Commodity Code': 50585803, 'Commodity Name': 'Non GMO drittler white nest shallots'}, page_content='food beverage and tobacco products non gmo fresh vegetables non gmo shallots non gmo drittler white nest shallots'),
#   np.float32(0.2342273)),
#  (Document(id='84cba531-85f4-44a5-b8ac-a6c7f8267bba', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50400000, 'Family Name': 'Fresh vegetables', 'Class Code': 50401700, 'Class Name': 'Avocados', 'Commodity Code': 50401706, 'Commodity Name': 'Beta avocados'}, page_content='food beverage and tobacco products fresh vegetables avocados beta avocados'),
#   np.float32(0.23334038)),
#  (Document(id='2b3a4013-2f63-4431-8ffe-faedb624ffbe', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50320000, 'Family Name': 'Dried fruit', 'Class Code': 50324600, 'Class Name': 'Dried melons', 'Commodity Code': 50324636, 'Commodity Name': 'Dried peacock melons'}, page_content='food beverage and tobacco products dried fruit dried melons dried peacock melons'),
#   np.float32(0.23307413)),
#  (Document(id='6c62f4bf-583d-4715-8716-86d5b4a0e565', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10310000, 'Family Name': 'Fresh cut blooms of high species or variety count flowers', 'Class Code': 10317300, 'Class Name': 'Fresh cut tulips', 'Commodity Code': 10317346, 'Commodity Name': 'Fresh cut parrot rococo red tulip'}, page_content='live plant and animal material and accessories and supplies fresh cut blooms of high species or variety count flowers fresh cut tulips fresh cut parrot rococo red tulip'),
#   np.float32(0.233015)),
#  (Document(id='42437423-1ad6-4f81-a837-fa47456c56ea', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50590000, 'Family Name': 'Dried Non GMO vegetables', 'Class Code': 50591700, 'Class Name': 'Dried Non GMO avocados', 'Commodity Code': 50591733, 'Commodity Name': 'Dried Non GMO guatemalan seedling avocados'}, page_content='food beverage and tobacco products dried non gmo vegetables dried non gmo avocados dried non gmo guatemalan seedling avocados'),
#   np.float32(0.23297781)),
#  (Document(id='b329fddc-b014-4923-a9b8-aa4302a9ee2f', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50400000, 'Family Name': 'Fresh vegetables', 'Class Code': 50401700, 'Class Name': 'Avocados', 'Commodity Code': 50401759, 'Commodity Name': 'Pinelli avocados'}, page_content='food beverage and tobacco products fresh vegetables avocados pinelli avocados'),
#   np.float32(0.23285997)),
#  (Document(id='7ecb0a82-6f2e-4f72-843d-4e19e3bbd6fa', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10310000, 'Family Name': 'Fresh cut blooms of high species or variety count flowers', 'Class Code': 10317300, 'Class Name': 'Fresh cut tulips', 'Commodity Code': 10317339, 'Commodity Name': 'Fresh cut parrot flaming tulip'}, page_content='live plant and animal material and accessories and supplies fresh cut blooms of high species or variety count flowers fresh cut tulips fresh cut parrot flaming tulip'),
#   np.float32(0.23265749)),
#  (Document(id='c7cf324e-22c1-4ea4-af69-7d60e10944c9', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50400000, 'Family Name': 'Fresh vegetables', 'Class Code': 50401700, 'Class Name': 'Avocados', 'Commodity Code': 50401707, 'Commodity Name': 'Biondo avocados'}, page_content='food beverage and tobacco products fresh vegetables avocados biondo avocados'),
#   np.float32(0.23255366)),
#  (Document(id='cbd72542-816a-48d4-a792-f9c635cc2980', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10150000, 'Family Name': 'Seeds and bulbs and seedlings and cuttings', 'Class Code': 10151800, 'Class Name': 'Spice crop seeds and seedlings', 'Commodity Code': 10151816, 'Commodity Name': 'Basil seeds or seedlings'}, page_content='live plant and animal material and accessories and supplies seeds and bulbs and seedlings and cuttings spice crop seeds and seedlings basil seeds or seedlings'),
#   np.float32(0.23242748)),
#  (Document(id='f24bce6d-2739-448e-bdbb-96ffdcd21749', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50400000, 'Family Name': 'Fresh vegetables', 'Class Code': 50401700, 'Class Name': 'Avocados', 'Commodity Code': 50401729, 'Commodity Name': 'Fuchs gwen avocados'}, page_content='food beverage and tobacco products fresh vegetables avocados fuchs gwen avocados'),
#   np.float32(0.23201716)),
#  (Document(id='cf3d7e46-73ee-4db5-8a4b-a1e263ea2af6', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10210000, 'Family Name': 'Live plants of high species or variety count flowers', 'Class Code': 10217300, 'Class Name': 'Live tulips', 'Commodity Code': 10217346, 'Commodity Name': 'Live parrot rococo red tulip'}, page_content='live plant and animal material and accessories and supplies live plants of high species or variety count flowers live tulips live parrot rococo red tulip'),
#   np.float32(0.23189831)),
#  (Document(id='cbe36c45-20ac-4531-bb9d-b92a8c0a01d2', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10150000, 'Family Name': 'Seeds and bulbs and seedlings and cuttings', 'Class Code': 10151600, 'Class Name': 'Cereal seeds', 'Commodity Code': 10151602, 'Commodity Name': 'Colza seeds'}, page_content='live plant and animal material and accessories and supplies seeds and bulbs and seedlings and cuttings cereal seeds colza seeds'),
#   np.float32(0.23182589)),
#  (Document(id='a215ba94-fa47-45ea-b550-571406c4e0bb', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50400000, 'Family Name': 'Fresh vegetables', 'Class Code': 50401700, 'Class Name': 'Avocados', 'Commodity Code': 50401719, 'Commodity Name': 'Catalina avocados'}, page_content='food beverage and tobacco products fresh vegetables avocados catalina avocados'),
#   np.float32(0.23182428)),
#  (Document(id='fe6170af-6115-4a9b-b066-fd050cda11ee', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10210000, 'Family Name': 'Live plants of high species or variety count flowers', 'Class Code': 10217300, 'Class Name': 'Live tulips', 'Commodity Code': 10217347, 'Commodity Name': 'Live parrot weber tulip'}, page_content='live plant and animal material and accessories and supplies live plants of high species or variety count flowers live tulips live parrot weber tulip'),
#   np.float32(0.2316891)),
#  (Document(id='f9c57a55-b5e3-4051-8568-3b7e67b06a84', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50480000, 'Family Name': 'Fresh vegetable purees', 'Class Code': 50481800, 'Class Name': 'Avocado purees', 'Commodity Code': 50481833, 'Commodity Name': 'Guatemalan seedling avocado purees'}, page_content='food beverage and tobacco products fresh vegetable purees avocado purees guatemalan seedling avocado purees'),
#   np.float32(0.23124593)),
#  (Document(id='e4c25006-4f8e-48d8-9d99-fb4596fdb358', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10320000, 'Family Name': 'Fresh cut blooms of low species or variety count flowers', 'Class Code': 10326000, 'Class Name': 'Fresh cut single species or varieties of flowers', 'Commodity Code': 10326005, 'Commodity Name': 'Fresh cut bird of paradise'}, page_content='live plant and animal material and accessories and supplies fresh cut blooms of low species or variety count flowers fresh cut single species or varieties of flowers fresh cut bird of paradise'),
#   np.float32(0.23102587)),
#  (Document(id='cb76afb8-c82e-454d-ae7c-90c044d69469', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50400000, 'Family Name': 'Fresh vegetables', 'Class Code': 50401700, 'Class Name': 'Avocados', 'Commodity Code': 50401736, 'Commodity Name': 'haas avocados'}, page_content='food beverage and tobacco products fresh vegetables avocados haas avocados'),
#   np.float32(0.23075962)),
#  (Document(id='af660ef1-98e9-4398-9e3d-6e2bd38b5109', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50310000, 'Family Name': 'Organic fresh fruits', 'Class Code': 50314600, 'Class Name': 'Organic melons', 'Commodity Code': 50314636, 'Commodity Name': 'Organic peacock melons'}, page_content='food beverage and tobacco products organic fresh fruits organic melons organic peacock melons'),
#   np.float32(0.23059714)),
#  (Document(id='e434eb1f-f1a6-430b-9983-6cb9f2430e41', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50400000, 'Family Name': 'Fresh vegetables', 'Class Code': 50401700, 'Class Name': 'Avocados', 'Commodity Code': 50401763, 'Commodity Name': 'Reed avocados'}, page_content='food beverage and tobacco products fresh vegetables avocados reed avocados'),
#   np.float32(0.23053122)),
#  (Document(id='eb10021c-e365-441b-9c6a-c50096ad0c7a', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50450000, 'Family Name': 'Frozen organic vegetables', 'Class Code': 50451700, 'Class Name': 'Frozen organic avocados', 'Commodity Code': 50451776, 'Commodity Name': 'Frozen organic west indian seedling avocados'}, page_content='food beverage and tobacco products frozen organic vegetables frozen organic avocados frozen organic west indian seedling avocados'),
#   np.float32(0.23035097)),
#  (Document(id='472fb7d1-ba80-491c-a73c-7765062e167d', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50400000, 'Family Name': 'Fresh vegetables', 'Class Code': 50401700, 'Class Name': 'Avocados', 'Commodity Code': 50401724, 'Commodity Name': 'Donnie avocados'}, page_content='food beverage and tobacco products fresh vegetables avocados donnie avocados'),
#   np.float32(0.23021376)),
#  (Document(id='5eea2e6c-b1a8-42b8-ac16-1d47d7d9ef07', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10150000, 'Family Name': 'Seeds and bulbs and seedlings and cuttings', 'Class Code': 10151800, 'Class Name': 'Spice crop seeds and seedlings', 'Commodity Code': 10151815, 'Commodity Name': 'Kudzu seeds or seedlings'}, page_content='live plant and animal material and accessories and supplies seeds and bulbs and seedlings and cuttings spice crop seeds and seedlings kudzu seeds or seedlings'),
#   np.float32(0.23019844)),
#  (Document(id='d0425f2d-b9ab-4fed-a2fa-eb85520022bc', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10410000, 'Family Name': 'Dried cut blooms of high species or variety count flowers', 'Class Code': 10417300, 'Class Name': 'Dried cut tulips', 'Commodity Code': 10417346, 'Commodity Name': 'Dried cut parrot rococo red tulip'}, page_content='live plant and animal material and accessories and supplies dried cut blooms of high species or variety count flowers dried cut tulips dried cut parrot rococo red tulip'),
#   np.float32(0.22993743)),
#  (Document(id='e8d4c050-696b-41a3-b6b6-6a31f2b1b09e', metadata={'Segment Code': 50000000, 'Segment Name': 'Food Beverage and Tobacco Products', 'Family Code': 50590000, 'Family Name': 'Dried Non GMO vegetables', 'Class Code': 50591700, 'Class Name': 'Dried Non GMO avocados', 'Commodity Code': 50591776, 'Commodity Name': 'Dried Non GMO west indian seedling avocados'}, page_content='food beverage and tobacco products dried non gmo vegetables dried non gmo avocados dried non gmo west indian seedling avocados'),
#   np.float32(0.22842276)),
#  (Document(id='d574f031-c2d7-44d0-8729-66aa69067602', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10150000, 'Family Name': 'Seeds and bulbs and seedlings and cuttings', 'Class Code': 10151500, 'Class Name': 'Vegetable seeds and seedlings', 'Commodity Code': 10151536, 'Commodity Name': 'Caigua seeds or seedlings'}, page_content='live plant and animal material and accessories and supplies seeds and bulbs and seedlings and cuttings vegetable seeds and seedlings caigua seeds or seedlings'),
#   np.float32(0.22819138)),
#  (Document(id='d1607cb0-6953-45f2-bb52-5332c5bb2734', metadata={'Segment Code': 11000000, 'Segment Name': 'Mineral and Textile and Inedible Plant and Animal Materials', 'Family Code': 11130000, 'Family Name': 'Non edible animal products', 'Class Code': 11131600, 'Class Name': 'Other animal products', 'Commodity Code': 11131610, 'Commodity Name': 'Non-edible bird and poultry eggs'}, page_content='mineral and textile and inedible plant and animal materials non edible animal products other animal products non-edible bird and poultry eggs'),
#   np.float32(0.22818083)),
#  (Document(id='140ee3b5-4e86-4c2e-afa2-b60e1bbffe2e', metadata={'Segment Code': 10000000, 'Segment Name': 'Live Plant and Animal Material and Accessories and Supplies', 'Family Code': 10410000, 'Family Name': 'Dried cut blooms of high species or variety count flowers', 'Class Code': 10417300, 'Class Name': 'Dried cut tulips', 'Commodity Code': 10417339, 'Commodity Name': 'Dried cut parrot flaming tulip'}, page_content='live plant and animal material and accessories and supplies dried cut blooms of high species or variety count flowers dried cut tulips dried cut parrot flaming tulip'),
#   np.float32(0.22779608))]

# %%
# retirver=loaded_vectorstore.as_retriever(
#     search_type="similarity",
#     search_kwargs={"k":3}
# )
# retirver.stream(input="bird seeds parrot food")

# %%
search_queries=pd.read_csv("G:/Dylog_Internship_Assessments/data/dylog_search_queries_unspsc.csv")
search_queries.head()
# Out:
#               Search Query     UNSPSC Commodity Name
# 0               PVC INSERT  PVC plastic pipe adapter
# 1     Snap-In Bend Support          Plumbing hangers
# 2       BACKSTOP WELL TANK       Water storage tanks
# 3  RADFIT 3/4 BEND SUPPORT          Plumbing hangers
# 4                SMOKE TEE     Carbon steel pipe tee

# %%
class HybridRetriever:
    def __init__(self, df, vectorstore, embeddings):
        from rank_bm25 import BM25Okapi
        self.df = df
        self.vectorstore = vectorstore
        self.embeddings = embeddings
        # BM25 initialization
        self.tokenized_docs = [d.lower().split() for d in df['Commodity Name'].tolist()]
        self.bm25 = BM25Okapi(self.tokenized_docs)
        print("BM25 index ready.")

    def retrieve(self, query, top_k=50):
        # Semantic
        sem_results = self.vectorstore.similarity_search_with_score(query, k=top_k)
        for c in sem_results:
            c['sem_score'] = float(c.metadata.get('score', 1.0))  # fallback
        # Lexical BM25
        tokenized_query = query.lower().split()
        bm25_scores = self.bm25.get_scores(tokenized_query)
        top_indices = np.argsort(-bm25_scores)[:top_k]
        lex_results = []
        for idx in top_indices:
            lex_results.append({
                'doc_text': df.iloc[idx]['Commodity Name'],
                'metadata': df.iloc[idx].to_dict(),
                'lex_score': float(bm25_scores[idx])
            })
        # Merge sem + lex, deduplicate by doc_text
        merged = {c['doc_text']: c for c in sem_results}
        for c in lex_results:
            if c['doc_text'] in merged:
                merged[c['doc_text']]['lex_score'] = c['lex_score']
            else:
                merged[c['doc_text']] = c
        return list(merged.values())

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import numpy as np

class CrossEncoderReranker:
    def __init__(self, model_name="cross-encoder/ms-marco-MiniLM-L-6-v2", device=None):
        """
        Initialize the cross-encoder reranker.
        model_name: HuggingFace model suitable for cross-encoder reranking
        device: 'cuda' or 'cpu'
        """
        self.device = device or ("cuda" if torch.cuda.is_available() else "cpu")
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.model = AutoModelForSequenceClassification.from_pretrained(model_name)
        self.model.to(self.device)
        self.model.eval()

    def rerank(self, query, candidates, top_n=5):
        """
        Rerank candidates given a query.
        query: str
        candidates: list of dicts, each containing 'doc_text' and optionally 'metadata'
        top_n: number of top candidates to return
        """
        candidate_texts = [c['doc_text'] for c in candidates]

        # Encode query-candidate pairs
        encodings = self.tokenizer([query]*len(candidate_texts), candidate_texts,
                                   padding=True, truncation=True, return_tensors="pt").to(self.device)

        with torch.no_grad():
            scores = self.model(**encodings).logits.squeeze(-1)
            scores = scores.cpu().numpy()

        # Attach scores to candidates
        for i, cand in enumerate(candidates):
            cand['cross_score'] = float(scores[i])

        # Sort by score descending
        reranked = sorted(candidates, key=lambda x: x['cross_score'], reverse=True)

        return reranked[:top_n]

# ---------------------------
# Example Usage
# ---------------------------
# Initialize reranker
reranker = CrossEncoderReranker()

# Query
query_text = "PVC INSERT"
#addressing the search queries sample
candidates=loaded_vectorstore.similarity_search_with_score(query=query_text,k=50)
candidate_dicts = [{'doc_text': d.page_content, 'metadata': d.metadata} for d in candidates]
# Suppose candidates is your top-k list from FAISS/BM25 hybrid retriever
# candidates = [{'doc_text': "...", 'metadata': {...}}, ...] 

top_n = 5
reranked_results = reranker.rerank(query_text, candidate_dicts, top_n=top_n)

# Display
for i, r in enumerate(reranked_results, 1):
    print(f"{i}. Score: {r['cross_score']:.4f} | Candidate: {r['doc_text']}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 54
#      52 #addressing the search queries sample
#      53 candidates=loaded_vectorstore.similarity_search_with_score(query=query_text,k=50)
# ---> 54 candidate_dicts = [{'doc_text': d.page_content, 'metadata': d.metadata} for d in candidates]
#      55 # Suppose candidates is your top-k list from FAISS/BM25 hybrid retriever
#      56 # candidates = [{'doc_text': "...", 'metadata': {...}}, ...]
#      58 top_n = 5
#
# AttributeError: 'tuple' object has no attribute 'page_content'

# %%
import numpy as np

class ScoreMerger:
    """
    Combines hybrid retriever scores (semantic + lexical) with cross-encoder scores
    and produces a final ranked list of candidates.
    """
    def __init__(self, alpha=0.5, beta=0.5):
        """
        alpha: weight for hybrid iever score
        beta: weight for cross-encoder score
        alpha + beta should ideally sum to 1
        """
        self.alpha = alpha
        self.beta = beta

    def normalize_scores(self, scores):
        """Normalize a list/array of scores to 0-1 range"""
        scores = np.array(scores, dtype=np.float32)
        min_s = scores.min()
        max_s = scores.max()
        if max_s - min_s == 0:
            return np.ones_like(scores)  # all same score
        return (scores - min_s) / (max_s - min_s)

    def merge(self, candidates):
        """
        candidates: list of dicts with keys:
            - 'sem_score' : hybrid iever score
            - 'lex_score' : lexical score (optional)
            - 'cross_score' : cross-encoder score
            - 'doc_text' : document text
            - 'metadata' : optional metadata
        Returns:
            list of candidates sorted by final combined score
        """
        sem_scores = [c.get("sem_score", 0) for c in candidates]
        lex_scores = [c.get("lex_score", 0) for c in candidates]
        cross_scores = [c.get("cross_score", 0) for c in candidates]

        # Combine semantic + lexical hybrid score first
        hybrid_scores = np.array(sem_scores) + np.array(lex_scores)
        hybrid_scores = self.normalize_scores(hybrid_scores)
        cross_scores = self.normalize_scores(cross_scores)

        # Weighted combination
        final_scores = self.alpha * hybrid_scores + self.beta * cross_scores

        # Attach final score to candidates
        for i, c in enumerate(candidates):
            c["final_score"] = float(final_scores[i])

        # Sort descending
        reranked = sorted(candidates, key=lambda x: x["final_score"], reverse=True)
        return reranked

# %%
# Suppose you have candidates from your hybrid iever
# candidates = loaded_vectorstore.similarity_search(query="PVC INSERT", k=50)
# and cross-encoder scores already attached

merger = ScoreMerger(alpha=0.4, beta=0.6)  # tweak weights if needed
final_ranked = merger.merge(candidate_dicts)

# Display top 5
for i, c in enumerate(final_ranked[:5], 1):
    print(f"{i}. Score: {c['final_score']:.4f} | Candidate: {c['doc_text']}")
# Out:
# 1. Score: 1.0000 | Candidate: distribution and conditioning systems and equipment and components pipe piping and pipe fittings pipe connectors pvc plastic pipe connector
# 2. Score: 0.9934 | Candidate: manufacturing components and supplies adhesives and sealants tape polyvinyl chloride pvc tape
# 3. Score: 0.9795 | Candidate: manufacturing components and supplies moldings thermoplastic molding inserts thermoplastic gas assisted injection molding insert
# 4. Score: 0.9687 | Candidate: distribution and conditioning systems and equipment and components pipe piping and pipe fittings pipe plugs pvc plastic pipe plug
# 5. Score: 0.9496 | Candidate: manufacturing components and supplies moldings thermoplastic molding inserts thermoplastic high precision injection molding insert

# %%
queries_list = search_queries.to_dict('records')

# Initialize
retriever = HybridRetriever(df, loaded_vectorstore, embeddings)
reranker = CrossEncoderReranker()
merger = ScoreMerger(alpha=0.5, beta=0.5)

# Evaluation accumulators
top1_correct = 0
top5_correct = 0
top10_correct = 0
precision_at_5 = []
recall_at_5 = []

# Loop through queries
for q in queries_list:
    query_text = q['Search Query']
    true_label = q['UNSPSC Commodity Name']

    # Step 1: Hybrid retrieval
    candi = retriever.retrieve(query_text, top_k=50)

    # Step 2: Cross-encoder rerank top 10
    candi = reranker.rerank(query_text, candidates, top_n=10)

    # Step 3: Merge scores (weighted)
    final_candidates = merger.merge(candi)

    # Step 4: Evaluate Top-K
    top1 = [c['doc_text'] for c in final_candidates[:1]]
    top5 = [c['doc_text'] for c in final_candidates[:5]]
    top10 = [c['doc_text'] for c in final_candidates[:10]]

    top1_correct += int(true_label in top1)
    top5_correct += int(true_label in top5)
    top10_correct += int(true_label in top10)

    # Precision@5, Recall@5
    precision_at_5.append(int(true_label in top5)/5)
    recall_at_5.append(int(true_label in top5)/1)  # only one relevant per query

# -------------------------------
# Metrics
num_queries = len(queries_list)
print(f"Top-1 Accuracy: {top1_correct/num_queries*100:.2f}%")
print(f"Top-5 Accuracy: {top5_correct/num_queries*100:.2f}%")
print(f"Top-10 Accuracy: {top10_correct/num_queries*100:.2f}%")
print(f"Precision@5: {np.mean(precision_at_5)*100:.2f}%")
print(f"Recall@5: {np.mean(recall_at_5)*100:.2f}%")
# Out:
# BM25 index ready.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 21
#      18 true_label = q['UNSPSC Commodity Name']
#      20 # Step 1: Hybrid retrieval
# ---> 21 candi = retriever.retrieve(query_text, top_k=50)
#      23 # Step 2: Cross-encoder rerank top 10
#      24 candi = reranker.rerank(query_text, candidates, top_n=10)
#
# Cell In[58], line 16, in HybridRetriever.retrieve(self, query, top_k)
#      14 sem_results = self.vectorstore.similarity_search(query, k=top_k)
#      15 for c in sem_results:
# ---> 16     c['sem_score'] = float(c.metadata.get('score', 1.0))  # fallback
#      17 # Lexical BM25
#      18 tokenized_query = query.lower().split()
#
# TypeError: 'Document' object does not support item assignment

# %%
def convert_docs_to_dicts(results, include_scores=True):
    """
    Converts a list of Document objects (from LangChain/FAISS/BM25 ievers)
    into a standardized list of dictionaries.
    
    Args:
        results: list of (Document, score) tuples or just Document objects
        include_scores: whether to include 'sem_score' key (if scores are provided)

    Returns:
        List[dict] with keys: 'doc_text', 'metadata', 'sem_score' (optional)
    """
    converted = []
    for item in results:
        if isinstance(item, tuple):  # (Document, score)
            doc, score = item
            entry = {
                "doc_text": doc.page_content,
                "metadata": getattr(doc, "metadata", {}),
            }
            if include_scores:
                entry["sem_score"] = float(score)
        else:  # Just Document (no score)
            entry = {
                "doc_text": item.page_content,
                "metadata": getattr(item, "metadata", {}),
            }
            if include_scores:
                entry["sem_score"] = 0.0
        converted.append(entry)
    return converted

# %%
# -------------------------------
# Full Evaluation Pipeline Cell
# -------------------------------
import pandas as pd
import numpy as np
from sklearn.metrics import precision_score, recall_score

# -------------------------------
# Assume you already have:
# df = catalog dataframe
# loaded_vectorstore = FAISS vectorstore
# embeddings = embedding model
# -------------------------------

# Hybrid Retriever Class (already implemented)
class HybridRetriever:
    def __init__(self, df, vectorstore, embeddings):
        from rank_bm25 import BM25Okapi
        self.df = df
        self.vectorstore = vectorstore
        self.embeddings = embeddings
        # BM25 initialization
        self.tokenized_docs = [d.lower().split() for d in df['Commodity Name'].tolist()]
        self.bm25 = BM25Okapi(self.tokenized_docs)
        print("BM25 index ready.")

    def retrieve(self, query, top_k=50):
        # Semantic
        sem_results = self.vectorstore.similarity_search_with_score(query, k=top_k)
        for c in sem_results:
            c['sem_score'] = float(c.metadata.get('score', 1.0))  # fallback
        # Lexical BM25
        tokenized_query = query.lower().split()
        bm25_scores = self.bm25.get_scores(tokenized_query)
        top_indices = np.argsort(-bm25_scores)[:top_k]
        lex_results = []
        for idx in top_indices:
            lex_results.append({
                'doc_text': df.iloc[idx]['Commodity Name'],
                'metadata': df.iloc[idx].to_dict(),
                'lex_score': float(bm25_scores[idx])
            })
        # Merge sem + lex, deduplicate by doc_text
        merged = {c['doc_text']: c for c in sem_results}
        for c in lex_results:
            if c['doc_text'] in merged:
                merged[c['doc_text']]['lex_score'] = c['lex_score']
            else:
                merged[c['doc_text']] = c
        return list(merged.values())

# Cross-Encoder Reranker Class (already implemented)
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch

class CrossEncoderReranker:
    def __init__(self, model_name="cross-encoder/ms-marco-MiniLM-L-6-v2", device=None):
        self.device = device or ("cuda" if torch.cuda.is_available() else "cpu")
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.model = AutoModelForSequenceClassification.from_pretrained(model_name)
        self.model.to(self.device)
        self.model.eval()

    def rerank(self, query, candidates, top_n=5):
        candidate_texts = [c['doc_text'] for c in candidates]
        encodings = self.tokenizer([query]*len(candidate_texts), candidate_texts,
                                   padding=True, truncation=True, return_tensors="pt").to(self.device)
        with torch.no_grad():
            scores = self.model(**encodings).logits.squeeze(-1)
            scores = scores.cpu().numpy()
        for i, cand in enumerate(candidates):
            cand['cross_score'] = float(scores[i])
        reranked = sorted(candidates, key=lambda x: x['cross_score'], reverse=True)
        return reranked[:top_n]

# Score Merger Class (already implemented)
class ScoreMerger:
    def __init__(self, alpha=0.5, beta=0.5):
        self.alpha = alpha
        self.beta = beta
    def normalize_scores(self, scores):
        scores = np.array(scores, dtype=np.float32)
        min_s, max_s = scores.min(), scores.max()
        if max_s - min_s == 0:
            return np.ones_like(scores)
        return (scores - min_s) / (max_s - min_s)
    def merge(self, candidates):
        sem_scores = [c.get('sem_score',0) for c in candidates]
        lex_scores = [c.get('lex_score',0) for c in candidates]
        cross_scores = [c.get('cross_score',0) for c in candidates]
        hybrid_scores = self.normalize_scores(np.array(sem_scores)+np.array(lex_scores))
        cross_scores = self.normalize_scores(cross_scores)
        final_scores = self.alpha*hybrid_scores + self.beta*cross_scores
        for i, c in enumerate(candidates):
            c['final_score'] = float(final_scores[i])
        return sorted(candidates, key=lambda x: x['final_score'], reverse=True)

# -------------------------------
# Load labeled queries
queries_df = pd.read_csv("G:/Dylog_Internship_Assessments/data/dylog_search_queries_unspsc.csv")
queries_list = queries_df.to_dict('records')

# Initialize
retriever = HybridRetriever(df, loaded_vectorstore, embeddings)
reranker = CrossEncoderReranker()
merger = ScoreMerger(alpha=0.5, beta=0.5)

# Evaluation accumulators
top1_correct = 0
top5_correct = 0
top10_correct = 0
precision_at_5 = []
recall_at_5 = []

# Loop through queries
for q in queries_list:
    query_text = q['Search Query']
    true_label = q['UNSPSC Commodity Name']

    # Step 1: Hybrid retrieval
    candidates = retriever.retrieve(query_text, top_k=50)

    # Step 2: Cross-encoder rerank top 10
    candidates = reranker.rerank(query_text, candidates, top_n=10)

    # Step 3: Merge scores (weighted)
    final_candidates = merger.merge(candidates)

    # Step 4: Evaluate Top-K
    top1 = [c['doc_text'] for c in final_candidates[:1]]
    top5 = [c['doc_text'] for c in final_candidates[:5]]
    top10 = [c['doc_text'] for c in final_candidates[:10]]

    top1_correct += int(true_label in top1)
    top5_correct += int(true_label in top5)
    top10_correct += int(true_label in top10)

    # Precision@5, Recall@5
    precision_at_5.append(int(true_label in top5)/5)
    recall_at_5.append(int(true_label in top5)/1)  # only one relevant per query

# -------------------------------
# Metrics
num_queries = len(queries_list)
print(f"Top-1 Accuracy: {top1_correct/num_queries*100:.2f}%")
print(f"Top-5 Accuracy: {top5_correct/num_queries*100:.2f}%")
print(f"Top-10 Accuracy: {top10_correct/num_queries*100:.2f}%")
print(f"Precision@5: {np.mean(precision_at_5)*100:.2f}%")
print(f"Recall@5: {np.mean(recall_at_5)*100:.2f}%")
# Out:
# BM25 index ready.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 121
#     118 true_label = q['UNSPSC Commodity Name']
#     120 # Step 1: Hybrid retrieval
# --> 121 gotten = retriever.retrieve(query_text, top_k=50)
#     123 # Step 2: Cross-encoder rerank top 10
#     124 gotten = reranker.rerank(query_text, gotten, top_n=10)
#
# Cell In[68], line 31, in HybridRetriever.retrieve(self, query, top_k)
#      29 sem_results = self.vectorstore.similarity_search(query, k=top_k)
#      30 for c in sem_results:
# ---> 31     c['sem_score'] = float(c.metadata.get('score', 1.0))  # fallback
#      32 # Lexical BM25
#      33 tokenized_query = query.lower().split()
#
# TypeError: 'Document' object does not support item assignment

# %%
# -------------------------------
# 📦 Imports
# -------------------------------
import pandas as pd
import numpy as np
from sklearn.metrics import precision_score, recall_score
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
from rank_bm25 import BM25Okapi

# -------------------------------
# 🧩 Utility — Convert Documents
# -------------------------------
def convert_docs_to_dicts(results, include_scores=True):
    """
    Converts Document objects (or tuples) from retrievers to a list of dicts.
    Ensures consistent format across FAISS and BM25 results.
    """
    converted = []
    for item in results:
        if isinstance(item, tuple):  # (Document, score)
            doc, score = item
            entry = {
                "doc_text": doc.page_content,
                "metadata": getattr(doc, "metadata", {}),
            }
            if include_scores:
                entry["sem_score"] = float(score)
        else:  # Just Document
            entry = {
                "doc_text": item.page_content,
                "metadata": getattr(item, "metadata", {}),
            }
            if include_scores:
                entry["sem_score"] = 0.0
        converted.append(entry)
    return converted


# -------------------------------
# ⚙️ Hybrid Retriever
# -------------------------------
class HybridRetriever:
    def __init__(self, df, vectorstore, embeddings):
        self.df = df
        self.vectorstore = vectorstore
        self.embeddings = embeddings
        self.tokenized_docs = [d.lower().split() for d in df['Commodity Name'].tolist()]
        self.bm25 = BM25Okapi(self.tokenized_docs)
        print("✅ BM25 index ready.")

    def retrieve(self, query, top_k=50):
        # Semantic retrieval (FAISS)
        sem_results = self.vectorstore.similarity_search_with_score(query, k=top_k)
        sem_candidates = convert_docs_to_dicts(sem_results)

        # Lexical retrieval (BM25)
        tokenized_query = query.lower().split()
        bm25_scores = self.bm25.get_scores(tokenized_query)
        top_indices = np.argsort(-bm25_scores)[:top_k]
        lex_results = [
            {
                'doc_text': self.df.iloc[idx]['Commodity Name'],
                'metadata': self.df.iloc[idx].to_dict(),
                'lex_score': float(bm25_scores[idx])
            }
            for idx in top_indices
        ]

        # Merge & deduplicate
        merged = {c['doc_text']: c for c in sem_candidates}
        for c in lex_results:
            if c['doc_text'] in merged:
                merged[c['doc_text']]['lex_score'] = c['lex_score']
            else:
                merged[c['doc_text']] = c
        return list(merged.values())


# -------------------------------
# 🤖 Cross-Encoder Reranker
# -------------------------------
class CrossEncoderReranker:
    def __init__(self, model_name="cross-encoder/ms-marco-MiniLM-L-6-v2", device=None):
        self.device = device or ("cuda" if torch.cuda.is_available() else "cpu")
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.model = AutoModelForSequenceClassification.from_pretrained(model_name)
        self.model.to(self.device)
        self.model.eval()

    def rerank(self, query, candidates, top_n=10):
        candidate_texts = [c['doc_text'] for c in candidates]
        encodings = self.tokenizer([query]*len(candidate_texts), candidate_texts,
                                   padding=True, truncation=True, return_tensors="pt").to(self.device)
        with torch.no_grad():
            scores = self.model(**encodings).logits.squeeze(-1)
            scores = scores.cpu().numpy()
        for i, cand in enumerate(candidates):
            cand['cross_score'] = float(scores[i])
        return sorted(candidates, key=lambda x: x['cross_score'], reverse=True)[:top_n]


# -------------------------------
# ⚖️ Score Merger
# -------------------------------
class ScoreMerger:
    def __init__(self, alpha=0.35, beta=0.65):
        self.alpha = alpha
        self.beta = beta

    def normalize_scores(self, scores):
        scores = np.array(scores, dtype=np.float32)
        if scores.size == 0:
            return scores
        min_s, max_s = scores.min(), scores.max()
        if max_s - min_s == 0:
            return np.ones_like(scores)
        return (scores - min_s) / (max_s - min_s)

    def merge(self, candidates):
        sem_scores = [c.get('sem_score', 0) for c in candidates]
        lex_scores = [c.get('lex_score', 0) for c in candidates]
        cross_scores = [c.get('cross_score', 0) for c in candidates]

        hybrid_scores = self.normalize_scores(np.array(sem_scores) + np.array(lex_scores))
        cross_scores = self.normalize_scores(cross_scores)

        final_scores = self.alpha * hybrid_scores + self.beta * cross_scores

        for i, c in enumerate(candidates):
            c['final_score'] = float(final_scores[i])

        return sorted(candidates, key=lambda x: x['final_score'], reverse=True)


# -------------------------------
# 🧮 Evaluation Pipeline
# -------------------------------
queries_df = pd.read_csv("G:/Dylog_Internship_Assessments/data/dylog_search_queries_unspsc.csv")
queries_list = queries_df.to_dict('records')

retriever = HybridRetriever(df, loaded_vectorstore, embeddings)
reranker = CrossEncoderReranker()
merger = ScoreMerger(alpha=0.4, beta=0.6)

top1_correct = top5_correct = top10_correct = 0
precision_at_5 = []
recall_at_5 = []

for q in queries_list:
    query_text = q['Search Query']
    true_label = q['UNSPSC Commodity Name']

    # Step 1: Retrieve hybrid results
    candidates = retriever.retrieve(query_text, top_k=50)

    # Step 2: Cross-encoder rerank
    candidates = reranker.rerank(query_text, candidates, top_n=10)

    # Step 3: Merge scores
    final_candidates = merger.merge(candidates)

    # Step 4: Evaluate
    top1 = [c['doc_text'] for c in final_candidates[:1]]
    top5 = [c['doc_text'] for c in final_candidates[:5]]
    top10 = [c['doc_text'] for c in final_candidates[:10]]

    top1_correct += int(true_label in top1)
    top5_correct += int(true_label in top5)
    top10_correct += int(true_label in top10)

    precision_at_5.append(int(true_label in top5) / 5)
    recall_at_5.append(int(true_label in top5) / 1)

# -------------------------------
# 📊 Final Metrics
# -------------------------------
num_queries = len(queries_list)
print(f"✅ Top-1 Accuracy:  {top1_correct / num_queries * 100:.2f}%")
print(f"✅ Top-5 Accuracy:  {top5_correct / num_queries * 100:.2f}%")
print(f"✅ Top-10 Accuracy: {top10_correct / num_queries * 100:.2f}%")
print(f"✅ Precision@5:     {np.mean(precision_at_5) * 100:.2f}%")
print(f"✅ Recall@5:        {np.mean(recall_at_5) * 100:.2f}%")
# Out:
# ✅ BM25 index ready.
# ✅ Top-1 Accuracy:  6.00%
# ✅ Top-5 Accuracy:  16.00%
# ✅ Top-10 Accuracy: 20.00%
# ✅ Precision@5:     3.20%
# ✅ Recall@5:        16.00%

# %%
import pandas as pd
import json

class TripletGenerator:
    """
    Generates (query, positive, negative) triplets for fine-tuning.
    Ensures no duplicate negatives per query.
    Exports triplets in JSONL format.
    """
    def __init__(self, queries_df, vectorstore, top_k=50, num_negatives=5):
        self.queries_df = queries_df
        self.vectorstore = vectorstore
        self.top_k = top_k
        self.num_negatives = num_negatives

    def generate_triplets(self):
        triplets = []

        # Group by unique query + positive combination
        grouped = self.queries_df.groupby(['Search Query', 'UNSPSC Commodity Name']).size().reset_index()

        for _, row in grouped.iterrows():
            query = row['Search Query']
            positive_label = row['UNSPSC Commodity Name']

            # Retrieve top-k candidates from hybrid retriever or FAISS
            candidates = self.vectorstore.similarity_search_with_score(query, k=self.top_k)

            # Extract candidate texts
            #candidate_texts = [c.page_content if hasattr(c, 'page_content') else c['doc_text'] for c in candidates]

            # Unpack documents from (Document, score) tuples
            candidate_texts = [doc.page_content for doc, score in candidates]

            # Select hard negatives: top N that are NOT the positive
            negatives = []
            for c in candidate_texts:
                if c != positive_label and c not in negatives:
                    negatives.append(c)
                if len(negatives) >= self.num_negatives:
                    break

            if negatives:  # only keep if at least one negative
                triplets.append({
                    "query": query,
                    "positive": positive_label,
                    "negatives": negatives
                })

        return triplets

    def save_jsonl(self, triplets, file_path):
        """
        Saves the triplets as JSONL (one JSON object per line)
        """
        with open(file_path, 'w', encoding='utf-8') as f:
            for t in triplets:
                f.write(json.dumps(t) + "\n")

# ---------------------------
# Example usage
# ---------------------------
queries_df = pd.read_csv("G:/Dylog_Internship_Assessments/data/dylog_search_queries_unspsc.csv")

triplet_gen = TripletGenerator(queries_df, loaded_vectorstore, top_k=50, num_negatives=5)
triplets = triplet_gen.generate_triplets()

# Save as JSONL
triplet_gen.save_jsonl(triplets, "triplets_dataset.jsonl")

# Quick preview
print(triplets[:3])
# Out:
# [{'query': '1 inch Viega PexPress coupling', 'positive': 'Brass pipe coupling', 'negatives': ['manufacturing components and supplies hardware couplings dura flex coupling', 'manufacturing components and supplies hardware couplings clamp coupling', 'manufacturing components and supplies hardware couplings miniature couplings', 'manufacturing components and supplies hardware couplings flange type flexible coupling', 'manufacturing components and supplies hardware couplings elastomeric couplings']}, {'query': '1-1/2 PVC DWV Trap Adapter', 'positive': 'PVC plastic pipe adapter', 'negatives': ['distribution and conditioning systems and equipment and components pipe piping and pipe fittings pipe adapters pvc plastic pipe adapter', 'distribution and conditioning systems and equipment and components fluid and gas distribution traps and strainers p trap', 'distribution and conditioning systems and equipment and components fluid and gas distribution traps and strainers j trap', 'distribution and conditioning systems and equipment and components pipe piping and pipe fittings pipe adapters cpvc plastic pipe adapter', 'distribution and conditioning systems and equipment and components fluid and gas distribution traps and strainers s trap']}, {'query': '1-1/2" BRASS GAS STOP VALVE LEVER HANDLE', 'positive': 'Ball valves', 'negatives': ['tools and general machinery hand tools dispensing tools natural gas dispenser', 'manufacturing components and supplies machinings standard precision machinings brass standard precision machining', 'tools and general machinery hand tools wrenches and drivers offset screw driver', 'tools and general machinery hand tools measuring and layout tools dial gauge stand', 'tools and general machinery hand tools holding and clamping tools adjustable widemouth pliers']}]

# %%
triplets[3:5]
# Out:
# [{'query': '1-1/4 x 1 ssfit bush 304',
#   'positive': 'Stainless steel pipe bushing',
#   'negatives': ['distribution and conditioning systems and equipment and components pipe piping and pipe fittings pipe bushings forged steel pipe bushing',
#    'distribution and conditioning systems and equipment and components pipe piping and pipe fittings pipe bushings stainless steel pipe bushing',
#    'manufacturing components and supplies bearings and bushings and wheels and gears bushings flange bushings',
#    'commercial and military and private vehicles and their accessories and components transportation components and systems suspension system components automotive bushings',
#    'manufacturing components and supplies bearings and bushings and wheels and gears bushings bushing sleeve']},
#  {'query': '3 x 3 x 2 PVC DWV Reducing Sanitary Tee',
#   'positive': 'PVC plastic pipe tee',
#   'negatives': ['distribution and conditioning systems and equipment and components pipe piping and pipe fittings pipe tees pvc plastic pipe tee',
#    'distribution and conditioning systems and equipment and components pipe piping and pipe fittings pipe tees cpvc plastic pipe tee',
#    'distribution and conditioning systems and equipment and components pipe piping and pipe fittings pipe tees hdpe plastic pipe tee',
#    'distribution and conditioning systems and equipment and components pipe piping and pipe fittings pipe tees carbon steel pipe tee',
#    'distribution and conditioning systems and equipment and components pipe piping and pipe fittings pipe tees stainless steel pipe tee']}]

# %%
import re
import pandas as pd

class ProductDescriptionCleaner:
    """
    Cleans the 'original_description' column in a product dataset.
    Can be extended with domain-specific replacements.
    """
    def __init__(self, domain_map=None):
        """
        domain_map: dict of word replacements for domain-specific terms.
        Future improvement :use a model or transformer to learn domain-specific replacements automatically instead of relying on a static map

        """
        self.domain_map = domain_map or {}

    def clean_text(self, text):
        if not isinstance(text, str):
            return ""
        text = text.lower()
        # Replace domain-specific abbreviations
        words = text.split()
        words = [self.domain_map.get(w, w) for w in words]
        text = " ".join(words)
        # Remove punctuation/special chars
        text = re.sub(r'[^\w\s]', ' ', text)
        # Remove arbitrary alphanumeric patterns of length >=6
        #text = re.sub(r'\b[a-zA-Z0-9]{6,}\b', '', text)
        # Remove extra spaces
        text = re.sub(r'\s+', ' ', text).strip()
        return text

    def clean_dataframe(self, df, column='original_description', new_column='cleaned_description'):
        """
        Cleans the specified column in a DataFrame and adds a new column with cleaned text.
        """
        df[new_column] = df[column].apply(self.clean_text)
        return df

# ---------------------------
# Example usage
# ---------------------------
domain_map = {
    "ss": "stainless steel",
    "pvc": "polyvinyl chloride",
    "vlv": "valve",
    "adpt": "adapter",
    "bush": "bushing"
}

df_products = pd.read_csv("G:/Dylog_Internship_Assessments/data/dylog_sample_product_unspsc.csv")
cleaner = ProductDescriptionCleaner(domain_map=domain_map)
df_products = cleaner.clean_dataframe(df_products, column='Original Description', new_column='cleaned_description')

df_products[['Original Description','cleaned_description']].head()
# Out:
#                                 Original Description  \
# 0  BW RG2PV75H6X 75 GAL LP GAS POWER VENTED WATER...
# 1  VERSIPRO BISC ELG CFWC WOOD SEAT SI SW-985 ORA...
# 2  2 3000# Forged Steel Threaded Half Coupling FP...
# 3                FUJ ASUH15KPAS 15000 BTU Standard-T
# 4  ALLIED 27W16 COMP ZP24K5E-PFV-830 2T R410A 230V-1
#
#                                  cleaned_description
# 0  bw rg2pv75h6x 75 gal lp gas power vented water...
# 1  versipro bisc elg cfwc wood seat si sw 985 ora...
# 2  2 3000 forged steel threaded half coupling fpt...
# 3                fuj asuh15kpas 15000 btu standard t
# 4  allied 27w16 comp zp24k5e pfv 830 2t r410a 230v 1

# %%
# -------------------------------
# 📦 Imports
# -------------------------------
import pandas as pd
import numpy as np
import re
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
from rank_bm25 import BM25Okapi

# -------------------------------
# 🧩 Text Cleaner
# -------------------------------
class TextCleaner:
    """
    Cleans original product descriptions or queries.
    """
    def __init__(self, mappings=None, remove_arbitrary_alphanum=True):
        """
        mappings: dict of replacements, e.g. {"PVC": "polyvinyl chloride"}
        remove_arbitrary_alphanum: removes patterns like 'rg2pv75h6x'
        """
        self.mappings = mappings or {}
        self.remove_arbitrary_alphanum = remove_arbitrary_alphanum
        self.arbitrary_pattern = re.compile(r'\b[a-zA-Z0-9]{6,}\b')  # 6+ chars alphanumeric

    def clean(self, text):
        text = str(text).lower()
        # Apply mapping replacements
        for k, v in self.mappings.items():
            text = text.replace(k.lower(), v.lower())
        # Remove arbitrary alphanumeric patterns
        if self.remove_arbitrary_alphanum:
            text = self.arbitrary_pattern.sub('', text)
        # Remove unwanted symbols except spaces
        text = re.sub(r'[^a-z0-9\s]', ' ', text)
        # Collapse multiple spaces
        text = re.sub(r'\s+', ' ', text).strip()
        return text

# -------------------------------
# ⚙️ Hybrid Retriever
# -------------------------------
class HybridRetriever:
    def __init__(self, df, vectorstore, embeddings, cleaner=None):
        self.df = df
        self.vectorstore = vectorstore
        self.embeddings = embeddings
        self.cleaner = cleaner
        self.tokenized_docs = [self.cleaner.clean(d) if cleaner else d.lower().split()
                               for d in df['Commodity Name'].tolist()]
        self.bm25 = BM25Okapi(self.tokenized_docs)
        print("✅ BM25 index ready.")

    def retrieve(self, query, top_k=50):
        query_clean = self.cleaner.clean(query) if self.cleaner else query
        # Semantic retrieval
        sem_results = self.vectorstore.similarity_search_with_score(query_clean, k=top_k)
        sem_candidates = convert_docs_to_dicts(sem_results)
        # Lexical BM25
        tokenized_query = query_clean.split()
        bm25_scores = self.bm25.get_scores(tokenized_query)
        top_indices = np.argsort(-bm25_scores)[:top_k]
        lex_results = [{"doc_text": self.df.iloc[idx]['Commodity Name'],
                        "metadata": self.df.iloc[idx].to_dict(),
                        "lex_score": float(bm25_scores[idx])} for idx in top_indices]
        # Merge
        merged = {c['doc_text']: c for c in sem_candidates}
        for c in lex_results:
            if c['doc_text'] in merged:
                merged[c['doc_text']]['lex_score'] = c['lex_score']
            else:
                merged[c['doc_text']] = c
        return list(merged.values())

# -------------------------------
# 🤖 Cross-Encoder Reranker
# -------------------------------
class CrossEncoderReranker:
    def __init__(self, model_name="cross-encoder/ms-marco-MiniLM-L-6-v2", device=None):
        self.device = device or ("cuda" if torch.cuda.is_available() else "cpu")
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.model = AutoModelForSequenceClassification.from_pretrained(model_name)
        self.model.to(self.device)
        self.model.eval()

    def rerank(self, query, candidates, top_n=10):
        candidate_texts = [c['doc_text'] for c in candidates]
        encodings = self.tokenizer([query]*len(candidate_texts), candidate_texts,
                                   padding=True, truncation=True, return_tensors="pt").to(self.device)
        with torch.no_grad():
            scores = self.model(**encodings).logits.squeeze(-1).cpu().numpy()
        for i, cand in enumerate(candidates):
            cand['cross_score'] = float(scores[i])
        return sorted(candidates, key=lambda x: x['cross_score'], reverse=True)[:top_n]

# -------------------------------
# ⚖️ Score Merger
# -------------------------------
class ScoreMerger:
    def __init__(self, alpha=0.35, beta=0.65):
        self.alpha = alpha
        self.beta = beta

    def normalize_scores(self, scores):
        scores = np.array(scores, dtype=np.float32)
        if scores.size == 0: return scores
        min_s, max_s = scores.min(), scores.max()
        return np.ones_like(scores) if max_s - min_s == 0 else (scores - min_s)/(max_s - min_s)

    def merge(self, candidates):
        sem_scores = [c.get('sem_score',0) for c in candidates]
        lex_scores = [c.get('lex_score',0) for c in candidates]
        cross_scores = [c.get('cross_score',0) for c in candidates]
        hybrid_scores = self.normalize_scores(np.array(sem_scores) + np.array(lex_scores))
        cross_scores = self.normalize_scores(cross_scores)
        final_scores = self.alpha*hybrid_scores + self.beta*cross_scores
        for i, c in enumerate(candidates):
            c['final_score'] = float(final_scores[i])
        return sorted(candidates, key=lambda x: x['final_score'], reverse=True)

# -------------------------------
# 🧮 Evaluator (with cleaning)
# -------------------------------
class Evaluator:
    def __init__(self, queries_list, retriever, reranker, merger, cleaner=None):
        self.queries_list = queries_list
        self.retriever = retriever
        self.reranker = reranker
        self.merger = merger
        self.cleaner = cleaner

    def evaluate(self, top_k=(1,5,10)):
        metrics = {'top1':0, 'top5':0, 'top10':0, 'precision@5':[], 'recall@5':[],
                   'segment_acc':0, 'family_acc':0, 'class_acc':0}
        for q in self.queries_list:
            query_text = self.cleaner.clean(q['Search Query']) if self.cleaner else q['Search Query']
            true_label = q['UNSPSC Commodity Name']
            true_segment = q.get('Segment Name', '')
            true_family = q.get('Family Name', '')
            true_class = q.get('Class Name', '')

            candidates = self.retriever.retrieve(query_text, top_k=50)
            candidates = self.reranker.rerank(query_text, candidates, top_n=top_k[2])
            final_candidates = self.merger.merge(candidates)

            pred_docs = [c['doc_text'] for c in final_candidates]
            pred_metadata = [c['metadata'] for c in final_candidates]

            metrics['top1'] += int(true_label in pred_docs[:1])
            metrics['top5'] += int(true_label in pred_docs[:5])
            metrics['top10'] += int(true_label in pred_docs[:10])
            metrics['precision@5'].append(int(true_label in pred_docs[:5])/5)
            metrics['recall@5'].append(int(true_label in pred_docs[:5])/1)
            metrics['segment_acc'] += int(any(true_segment==m.get('Segment Name','') for m in pred_metadata[:5]))
            metrics['family_acc'] += int(any(true_family==m.get('Family Name','') for m in pred_metadata[:5]))
            metrics['class_acc'] += int(any(true_class==m.get('Class Name','') for m in pred_metadata[:5]))

        N = len(self.queries_list)
        return { "Top-1 Accuracy": metrics['top1']/N*100,
                 "Top-5 Accuracy": metrics['top5']/N*100,
                 "Top-10 Accuracy": metrics['top10']/N*100,
                 "Precision@5": np.mean(metrics['precision@5'])*100,
                 "Recall@5": np.mean(metrics['recall@5'])*100,
                 "Segment Accuracy": metrics['segment_acc']/N*100,
                 "Family Accuracy": metrics['family_acc']/N*100,
                 "Class Accuracy": metrics['class_acc']/N*100 }

# -------------------------------
# 🔹 Example Usage
# -------------------------------
queries_df = pd.read_csv("G:/Dylog_Internship_Assessments/data/dylog_search_queries_unspsc.csv")
queries_list = queries_df.to_dict('records')

cleaner = TextCleaner(remove_arbitrary_alphanum=True)
retriever = HybridRetriever(df, loaded_vectorstore, embeddings, cleaner=cleaner)
reranker = CrossEncoderReranker()
merger = ScoreMerger(alpha=0.4, beta=0.6)

evaluator = Evaluator(queries_list, retriever, reranker, merger, cleaner=cleaner)
results = evaluator.evaluate()
for k,v in results.items():
    print(f"✅ {k}: {v:.2f}%")
# Out:
# ✅ BM25 index ready.
# ✅ Top-1 Accuracy: 0.00%
# ✅ Top-5 Accuracy: 0.00%
# ✅ Top-10 Accuracy: 0.00%
# ✅ Precision@5: 0.00%
# ✅ Recall@5: 0.00%
# ✅ Segment Accuracy: 0.00%
# ✅ Family Accuracy: 0.00%
# ✅ Class Accuracy: 0.00%
